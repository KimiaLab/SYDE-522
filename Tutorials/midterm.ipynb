# %% [markdown]
# # Section: Tutorials (25%)
#
# ## [12 pts] Principal Component Analysis
#
# Below is scatter plot of data collected from multivariate Gaussian distribution. It is 2-D data with shape `(5000, 2)`.

# %%
import libs.midterm as M
# %matplotlib inline

# %%
# get data for the question
data = M.get_data_for_ques1(l=1000)
M.plot_ques1(data, alpha=0.2)

# %% [markdown]
# First 10 values of data variables are shown below:

# %%
M.pd.DataFrame(data).head(10)
# Out:
#            0          1
# 0   2.307641  -0.766747
# 1   4.201383   6.895544
# 2  -1.425025   1.589337
# 3   8.585633  10.011310
# 4  -6.648210  -5.253754
# 5   4.580744   2.016547
# 6  12.530416   6.658200
# 7   1.904158   1.880882
# 8   9.618048   8.544929
# 9   6.964061  10.739248

# %% [markdown]
# ### [3 pts] General Questions
# 1.) **[1 pts]** What is approximate value of `np.mean(data, axis=0)` or mean of this distribution? Round it off to nearest integer.
#
# <br><br>
#
# 2.) **[2 pts]** What is sign of covariance $\sum_{1,2} = Cov(X_1, X_2)$ be (select only one):
#
# - Negative
# - Positive
# - Approximately zero
#
# ### [5 pts] Principal Component Analysis
#
# Lets say $v_1$ and $v_2$ are direction of principal components for the given data, such that $||V_1|| = ||V_2|| = 1$.
#
# 1.) **[2 pts]** Sketch and label $V_1$ and $V_2$ on the graph below. *Note:* $V_1$ and $V_2$ are unit vectors.

# %%
M.plot_ques1(data, alpha=0.1)

# %% [markdown]
# 2.) **[2 pts]** Write steps involved in finding all the Principal Components for a given data. (just write one line summarizing the step)
#
# - STEP 1: Make mean zero $\mu=0$ for given data. $M = M - mean(M, axis=0)$
# <br><br>
# - STEP 2:
# <br><br>
# - STEP 3:
# <br><br>
#
# 3.) **[1 pts]** Can we reconstruct data with 100% accuracy if we use all its Principal Components?
# 1. True
# 2. False
#
# 4.) **[2 pts]** For dimensionality reduction we select $n$ number of Principal Components where $n < d$ and $d$ is original dimension of a data-point. How do we select $n$ Principal Components from all the given Principal Components?
#
# <br><br>
# <br><br>
#
#
# ### [4 pts] PCA Application
#
# During tutorial we used PCA to extract Eigen-faces as shown in image below.

# %%
pca = M.train_pca_on_faces(n_eigen_faces=50)
M.plot_eigen_faces(pca)

# %% [markdown]
# 1.) **[2 pts]** Above image contains 50 Eigen-faces. What does each Eigen-face represent?
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# 2.) **[2 pts]** In the tutorial, I constructed my (Shivam's) face using Eigen-faces and achieved somewhat decent similarity. Briefly explain what would happen if we try to construct non-face image?
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>

# %% [markdown]
# ## [10 pts] KMeans Clustering
#
# ### [3 pts] General
# 1.) **[1 pts]** Is K-Means algorithm guaranteed to converge within finite number of steps?
# 1. True
# 2. False
#
# 2.) **[2 pts]** When K-Means is applied to half-moon dataset, it is unable to cluster each moon separately (Seen image below).
#
# ![](images/kmeans-moon.png)
#
# Explain why?
# <br><br>
# <br><br>
# <br><br>
#
# ### [7 pts] Color Quantization
# During tutorials, we performed the color quantization of a given image as shown in image below:
#
# ![](images/quant_kmeans.jpg)
#
# 1.) **[3 pts]** Briefly explain the overall process of quantizing a given image $I$? It is not required to write code but explain in such a way that it could be converted into a code. (please write steps or draw flow diagram)
#
# - STEP 1: Given an RGB image $I$ of size $[N \times M \times 3]$.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# 2.) **[1 pts]** What is size of an uncompressed $1000 \times 1000$ of RGB image (3 channels). Note: each R, G and B component takes 1 byte [0-255].
#
# <br><br>
# <br><br>
#
# 3.) **[3 pts]** Let say we are building a compression algorithm for an image by quantizing its colors. If we have $1000 \times 1000$ RGB image and quantize its colors with $K=256$, what would be the resulting size of the compressed image.
#
# **Hint:** All the colors in the images is quantized to list of 256 RGB colors. Each pixel of image can take one of these 256 color values (thus require limited memory). Total compressed size would include: 1) size of storing list of 256 RGB colors, 2) transformed $1000 \times 1000$ image.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# ## [2 pts] Ensembling
# 1.) **[2 pts]** During the tutorial, ensembling of classification models performed better than individual when `log-loss` was used as metric instead of `accuracy`. Explain why?
# <br><br>
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# ## [10 pts] Scenario Question: Bag of Words
#
# You are building a system to understand sentiment of a movie review. Sentiment could be
# either positive or negative. For example:
#
# **Positive:** It's almost impossible to put in words, but we have to try and give
# everyone what he truly deserve.
#
# In my modest opinion, Interstellar is the best Sci-Fi in human history.
# Believe it or not. It's the simple and the complicated, It's the usual and the
# different, It's the mind and the heart, It's an emotional and psychological
# journey through the unknown which has its own stunning visuals. It's an
# original story and thought-provoking masterpiece. [...]
#
# **Negative:** In the opening night, I walked out from the movie theater,
# totally disappointed to see one of my favorite directors has diminished himself
# to such a low lever of performance.
#
# Poorly developing plot, immature explanation of astrophysics, unbelievable
# and unrelated events and characters, especial effects leveled to a Disney comedy,
# and horrible music are only parts of my negative impression.
#
# Even Mathew McConaghey did not seem believable looking at her daughter, older
# than himself. Mat Damon probably did his career's worst acting. The robot was
# another annoying part. What did Anne Hathaway and two other guys add to the story? [...]
#
#
# **Note:** Each review contains various aspect of movie including its story, characters
# and  sentiment of statement is somewhere hidden in it. You collected up to million individual
# reviews from IMDB with 0 and 10 rating. Lets assume, review with a 0 rating exhibits
# negative sentiment whereas one with 10 is associated with positive sentiment.
#
# Now, you have labeled data with up to million records. You're planning to use Bag-of-word
# model for your sentiment analysis. You pre-process all reviews and extracted all the
# unique words used within all the reviews.
#
# 1.) **2 pts** Explain what the bag-of-words representation for an individual review would
# 	be (using unique words obtained from pre-process step)?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#
# 2.) **2 pts** How can you combine representations of review of all individuals for a given
# 	movies to get a bag-of-word representation for that movie?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#
# 3.) **2 pts** How can you cluster similar movies together? What kind of clustering
# algorithm would you use?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#
# 4.) **1 pts** There can be thousands of unique words extracted from all the million review. Comment on sparsity of your feature vector for each review?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#
# 5.) **2 pts** In tutorials, we grouped similar words into cluster using unsupervised `word2vec` method. Explain how this can improve this system?
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#     <br><br>
#
# 6.) **1 pts** Discuss one dis-advantage of your feature set for training a classifier  for discriminating the sentiments?
# <br><br>
# <br><br>
# <br><br>
# <br><br>
#
# ## [2 pts] Autoencoders
#
# 1.) **2 pts** What is Variational Autoencoder? Explain briefly.
# <br><br>
# <br><br>
# <br><br>
# <br><br>
